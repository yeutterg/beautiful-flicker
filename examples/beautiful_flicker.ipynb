# %%
# %matplotlib inline

bedtimebulb = (120, 0.0625, 'Bedtime Bulb')
incandescent = (120, 0.108, 'Incandescent 60 W')
soraa = (120, 0.552, 'Soraa Healthy')
lsg = (120, 0.274, 'LSG Goodnight')

from plot import ieee_par_1789_graphic

ieee_par_1789_graphic([bedtimebulb, incandescent, soraa, lsg], filename='out/Low Blue Flicker Comparison')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f5095e70e8b1> in <module>
#       8 from plot import ieee_par_1789_graphic
#       9
# ---> 10 ieee_par_1789_graphic([bedtimebulb, incandescent, soraa, lsg], filename='out/Low Blue Flicker Comparison')
#
# ~/Dropbox/Lighting Measurement/beautiful-flicker/plot.py in ieee_par_1789_graphic(data, figsize, filename, showred, showyellow, noriskcolor, max_freq, min_pct, suppress)
#      55     if showyellow:
#      56         lowrisk_region = [[1, 0.001], [1, 0.002], [8, 0.002], [90, 0.025], [90, 0.075], [1200, 1], [3000, 1], [100, 0.03], [100, 0.025], [100, 0.01], [10, 0.001]]
# ---> 57         lowrisk = plt.fill_between(lowrisk_region, fc='y', alpha=0.3)
#      58         plt.gca().add_patch(lowrisk)
#      59
#
# TypeError: fill_between() missing 1 required positional argument: 'y1'
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

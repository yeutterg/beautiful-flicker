# %%
# displays plots in this notebook
# %matplotlib inline 

# Since we are in the ./examples folder, add the root folder (../) to the path
import sys
sys.path.append('../')

# Import the Waveform class
from src.waveform import Waveform

# %%
from src.waveform import WaveformCollection
    
waveforms = WaveformCollection('../CSVs/2019-03-20/')
print('Waveforms: ' + str(waveforms.get_names()))
# Out:
# WARNING: Could not import waveform at file location ../CSVs/2019-03-20/IKEA_Lunnom.csv
# attempt to get argmin of an empty sequence
# Waveforms: ['Soraa Healthy', 'Ecosmart Candelabra LED', 'Sylvania 60W', 'Hue Color Day', 'Bedtime Bulb', 'GE Align PM', 'GE Classic LED', 'Hue Color Night', 'Feit 60W', 'LSG Goodnight', 'Sylvania 25W Candelabra', 'IKEA Lunnom', 'CFL', 'Hue Color Normal', 'Westinghouse 50W', 'Hue Color Evening', 'Old IKEA LED']

# %%
# from src.waveform import Waveform
# bedtime_bulb = Waveform('../CSVs/2019-03-20/Bedtime_Bulb.csv', 'Bedtime Bulb')

bedtime_bulb = waveforms.get('Bedtime Bulb')
bedtime_bulb.plot()

# %%
bedtime_bulb.plot_extrapolated()

# %%
soraa = waveforms.get('Soraa Healthy')
soraa.plot_extrapolated()

# %%
feit = waveforms.get('Feit 60W')
feit.plot_extrapolated()

# %%
sylvania = waveforms.get('Sylvania 60W')
sylvania.plot_extrapolated()

# %%
# hue_day = waveforms.get('Hue Color Day')
# hue_day.plot_extrapolated()

# %%
hue_normal = waveforms.get('Hue Color Normal')
hue_normal.plot_extrapolated()

# %%
ecosmart = waveforms.get('Ecosmart Candelabra LED')
ecosmart.plot_extrapolated()
